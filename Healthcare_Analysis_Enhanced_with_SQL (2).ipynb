# %% [markdown]
# # Introduction to the Healthcare Data Analysis Project
# Healthcare is a critical domain where data-driven decision-making can significantly enhance patient care, operational efficiency, and resource management. The Healthcare Data Analysis Project focuses on leveraging a comprehensive dataset to gain insights into patient demographics, medical conditions, hospital operations, and financial trends. By analyzing this dataset, we aim to uncover patterns, identify trends, and provide actionable recommendations that can improve healthcare services and outcomes.
#
#
# # Healthcare Dataset Information:
# Each column provides specific information about the patient, their admission, and the healthcare services provided, making this dataset suitable for various data analysis and modeling tasks in the healthcare domain. Here's a brief explanation of each column in the dataset -
#
# Patient_ID : The unique ID of the each patient.
#
# Name: This column represents the name of the patient associated with the healthcare record.
#
# Age: The age of the patient at the time of admission, expressed in years.
#
# Gender: Indicates the gender of the patient, either "Male" or "Female."
#
# Blood Type: The patient's blood type, which can be one of the common blood types (e.g., "A+", "O-", etc.).
#
# Medical Condition: This column specifies the primary medical condition or diagnosis associated with the patient, such as "Diabetes," "Hypertension," "Asthma," and more.
#
# Date of Admission: The date on which the patient was admitted to the healthcare facility.
#
# Doctor: The name of the doctor responsible for the patient's care during their admission.
#
# Hospital: Identifies the healthcare facility or hospital where the patient was admitted.
#
# Insurance Provider: This column indicates the patient's insurance provider, which can be one of several options, including "Aetna," "Blue Cross," "Cigna," "UnitedHealthcare," and "Medicare."
#
# Billing Amount: The amount of money billed for the patient's healthcare services during their admission. This is expressed as a floating-point number.
#
# Room Number: The room number where the patient was accommodated during their admission.
#
# Admission Type: Specifies the type of admission, which can be "Emergency," "Elective," or "Urgent," reflecting the circumstances of the admission.
#
# Discharge Date: The date on which the patient was discharged from the healthcare facility, based on the admission date and a random number of days within a realistic range.
#
# Medication: Identifies a medication prescribed or administered to the patient during their admission. Examples include "Aspirin," "Ibuprofen," "Penicillin," "Paracetamol," and "Lipitor."
#
# Test Results: Describes the results of a medical test conducted during the patient's admission. Possible values include "Normal," "Abnormal," or "Inconclusive," indicating the outcome of the test.

# %%
# Import necessary libraries
import pandas as pd  # For data manipulation and analysis
import numpy as np  # For numerical computations
import matplotlib.pyplot as plt  # For data visualization
import seaborn as sns  # For advanced visualization and aesthetics

# Load the healthcare dataset into a DataFrame
df = pd.read_csv('C:\\Users\\amulya shetty\\OneDrive\\Desktop\\Healthcare_dataset.csv')
df  # Display the DataFrame (first 5 rows by default)
# Out:
#       Patient_ID                  Name  Age  Gender Blood_Type  \
# 0            100       Tiffany Ramirez   81  Female         O-
# 1            101           Ruben Burns   35    Male         O+
# 2            102             Chad Byrd   61    Male         B-
# 3            103     Antonio Frederick   49    Male         B-
# 4            104   Mrs. Brandy Flowers   51    Male         O-
# ...          ...                   ...  ...     ...        ...
# 9995       10095            James Hood   83    Male         A+
# 9996       10096       Stephanie Evans   47  Female        AB+
# 9997       10097  Christopher Martinez   54    Male         B-
# 9998       10098           Amanda Duke   84    Male         A+
# 9999       10099             Eric King   20    Male         B-
#
#      Medical_Condition Admission_Date             Doctor  \
# 0             Diabetes     17-11-2022     Patrick Parker
# 1               Asthma     01-06-2023      Diane Jackson
# ...

# %%
# Overview of the dataset structure and memory usage
df.info()  # Provides column names, data types, and non-null counts
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Patient_ID          10000 non-null  int64
#  1   Name                10000 non-null  object
#  2   Age                 10000 non-null  int64
#  3   Gender              10000 non-null  object
#  4   Blood_Type          10000 non-null  object
#  5   Medical_Condition   10000 non-null  object
#  6   Admission_Date      10000 non-null  object
#  7   Doctor              10000 non-null  object
#  8   Hospital            10000 non-null  object
#  9   Insurance_Provider  10000 non-null  object
#  10  Billing_Amount      10000 non-null  float64
#  11  Room_Number         10000 non-null  int64
#  12  Admission_Type      10000 non-null  object
#  13  Discharge_Date      10000 non-null  object
#  14  Medication          10000 non-null  object
# ...

# %%
# Install pandasql for SQL-like querying if not already installed
# !pip install -q pandasql
from pandasql import sqldf

# Define a helper function for SQL queries
pysqldf = lambda q: sqldf(q, globals())

# %%
# Example SQL query: Retrieve top 5 patients with the highest billing amounts
query = '''
SELECT Patient_ID, Name, Billing_Amount 
FROM df 
ORDER BY Billing_Amount DESC 
LIMIT 5
'''
pysqldf(query)  # Execute the query and display the results
# Out:
#    Patient_ID             Name  Billing_Amount
# 0        8889      Daniel Hall     49995.90228
# 1        9484  Teresa Buchanan     49994.98474
# 2        3356         Roy Beck     49985.97307
# 3         834       Mary Stein     49974.80659
# 4        3626    Richard Jones     49974.29914

# %%
# data visualization

# %%
# Distribution of Patients by Age

import matplotlib.pyplot as plt
import seaborn as sns

# Distribution of Age
plt.figure(figsize=(10, 6))
sns.histplot(df['Age'], kde=True, bins=20, color='skyblue')
plt.title('Distribution of Patients by Age')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
# Gender Count

plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='Gender', palette='pastel')
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
# Average Billing Amount by Admission Type

# Bar plot of Average Billing Amount by Admission Type
plt.figure(figsize=(12, 6))
sns.barplot(data=df, x='Admission_Type', y='Billing_Amount', ci=None, palette='viridis')
plt.title('Average Billing Amount by Admission Type')
plt.xlabel('Admission Type')
plt.ylabel('Average Billing Amount')
plt.xticks(rotation=45)
plt.show()

# %%
# Patients Count by Blood Type

# Pie chart for Blood Type distribution
blood_type_counts = df['Blood_Type'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(blood_type_counts, labels=blood_type_counts.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('pastel'))
plt.title('Distribution of Patients by Blood Type')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame already loaded from MySQL

# Convert 'Date of Admission' to datetime for better analysis
df['Admission_Date'] = pd.to_datetime(df['Admission_Date'], infer_datetime_format=True)

# Group by 'Admission_Date' and calculate the mean 'Billing_Amount'
billing_trend = df.groupby('Admission_Date')['Billing_Amount'].mean()

# Plotting the trend of the average Billing Amount over time
plt.figure(figsize=(14, 6))
billing_trend.plot(color='orange', linewidth=2)
plt.title('Trend of Average Billing Amount Over Time')
plt.xlabel('Date of Admission')
plt.ylabel('Average Billing Amount')
plt.grid(True)
plt.show()

# %%
pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install mysql-connector-python pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector
from mysql.connector import Error

try:
    # Connect to MySQL database
    conn = mysql.connector.connect(
        host="127.0.0.1",
        user="root",
        password="shetty",
        database="healthcare"
    )
    if conn.is_connected():
        print("Connected to MySQL database.")

    cursor = conn.cursor()

    # Check if the table already exists
    cursor.execute("""
        SELECT COUNT(*)
        FROM information_schema.tables
        WHERE table_schema = 'healthcare' AND table_name = 'patients';
    """)
    result = cursor.fetchone()

    if result[0] == 1:
        print("Table 'patients' already exists.")
    else:
        # Create the 'patients' table if it does not exist
        cursor.execute("""
            CREATE TABLE patients (
                Patient_ID INT PRIMARY KEY,
                Name VARCHAR(255) NOT NULL,
                Age INT NOT NULL,
                Gender VARCHAR(50) NOT NULL,
                Blood_Type VARCHAR(10),
                Medical_Condition TEXT,
                Admission_Date DATETIME,
                Doctor VARCHAR(255),
                Hospital VARCHAR(255),
                Insurance_Provider VARCHAR(255),
                Billing_Amount DECIMAL(10, 2),
                Room_Number INT,
                Admission_Type VARCHAR(50),
                Discharge_Date DATETIME,
                Medication TEXT,
                Test_Results TEXT
            )
        """)
        print("Table 'patients' created successfully!")

    # Commit changes
    conn.commit()

except Error as e:
    print(f"Error: {e}")
finally:
    # Close cursor and connection
    if cursor:
        cursor.close()
    if conn.is_connected():
        conn.close()
        print("MySQL connection closed.")
# Out:
# Connected to MySQL database.
# Table 'patients' created successfully!
# MySQL connection closed.

# %%
import pandas as pd
from sqlalchemy import create_engine

# Path to your dataset (adjust the path if needed)
file_path = 'C:\\Users\\amulya shetty\\OneDrive\\Desktop\\Healthcare_dataset.csv'

# Load the dataset into a Pandas DataFrame
data = pd.read_csv(file_path)

# Create an engine for MySQL (replace 'your_host' with the correct host)
engine = create_engine("mysql+mysqlconnector://root:shetty@127.0.0.1/healthcare")

# Write the DataFrame to the MySQL table
data.to_sql('patients', con=engine, if_exists='replace', index=False)

print("Data loaded into the 'patients' table successfully!")
# Out:
# Data loaded into the 'patients' table successfully!

# %%
# Display the first few rows of the dataframe
print(data.head())
# Out:
#    Patient_ID                 Name  Age  Gender Blood_Type Medical_Condition  \
# 0         100      Tiffany Ramirez   81  Female         O-          Diabetes
# 1         101          Ruben Burns   35    Male         O+            Asthma
# 2         102            Chad Byrd   61    Male         B-           Obesity
# 3         103    Antonio Frederick   49    Male         B-            Asthma
# 4         104  Mrs. Brandy Flowers   51    Male         O-         Arthritis
#
#   Admission_Date          Doctor                   Hospital  \
# 0     17-11-2022  Patrick Parker           Wallace-Hamilton
# 1     01-06-2023   Diane Jackson  Burke, Griffin and Cooper
# 2     09-01-2019      Paul Baker                 Walton LLC
# 3     02-05-2020  Brian Chandler                 Garcia Ltd
# 4     09-07-2021  Dustin Griffin    Jones, Brown and Murray
#
#   Insurance_Provider  Billing_Amount  Room_Number Admission_Type  \
# 0           Medicare     37490.98336          146       Elective
# ...

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Patient_ID          10000 non-null  int64
#  1   Name                10000 non-null  object
#  2   Age                 10000 non-null  int64
#  3   Gender              10000 non-null  object
#  4   Blood_Type          10000 non-null  object
#  5   Medical_Condition   10000 non-null  object
#  6   Admission_Date      10000 non-null  object
#  7   Doctor              10000 non-null  object
#  8   Hospital            10000 non-null  object
#  9   Insurance_Provider  10000 non-null  object
#  10  Billing_Amount      10000 non-null  float64
#  11  Room_Number         10000 non-null  int64
#  12  Admission_Type      10000 non-null  object
#  13  Discharge_Date      10000 non-null  object
#  14  Medication          10000 non-null  object
# ...

# %%
# data visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import mysql.connector


db = mysql.connector.connect(host = "localhost",
                            username = "root",
                            password = "shetty",
                            database = "healthcare")

cur = db.cursor()

# %%
# Bar Plot for Top 5 Medical Conditions

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Execute the query
query = """
SELECT Medical_Condition, COUNT(*) AS patient_count
FROM patients
GROUP BY Medical_Condition
ORDER BY patient_count DESC
LIMIT 3;
"""
cur.execute(query)
data = cur.fetchall()

# Convert the result into a Pandas DataFrame
df = pd.DataFrame(data, columns=["Medical_Condition", "patient_count"])

# Visualization
plt.figure(figsize=(12, 6))
sns.barplot(x=df["patient_count"], y=df["Medical_Condition"], palette="viridis")
plt.title("Top Most Common Medical Conditions")
plt.xlabel("Number of Patients")
plt.ylabel("Medical Condition")
plt.show()

# %%
#  Pie Chart of Admission Types

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Query to fetch Admission Type distribution
query = """
SELECT Admission_Type, COUNT(*) AS admission_count
FROM patients
GROUP BY Admission_Type
ORDER BY admission_count DESC;
"""

# Execute the query
cur.execute(query)
data = cur.fetchall()

# Convert the result into a Pandas DataFrame
df = pd.DataFrame(data, columns=["Admission_Type", "admission_count"])

# Visualization
plt.figure(figsize=(8, 8))
plt.pie(
    df["admission_count"],
    labels=df["Admission_Type"],
    autopct='%1.1f%%',
    startangle=90,
    colors=sns.color_palette('pastel')
)
plt.title("Distribution of Admission Types")
plt.show()

# %%
# Top 5 Hospitals with the Most Patients

# Query to fetch top 5 hospitals with the most patients
query = """
SELECT Hospital, COUNT(*) AS patient_count
FROM patients
GROUP BY Hospital
ORDER BY patient_count DESC
LIMIT 5;
"""

cur.execute(query)
data = cur.fetchall()

# Convert the result into a Pandas DataFrame
df = pd.DataFrame(data, columns=["Hospital", "patient_count"])

# Visualization: Bar plot for top 5 hospitals
plt.figure(figsize=(12, 6))
sns.barplot(x="Hospital", y="patient_count", data=df, palette="Blues_d")
plt.title('Top 5 Hospitals with the Most Patients')
plt.xlabel('Hospital')
plt.ylabel('Number of Patients')
plt.xticks(rotation=45)
plt.show()

# %%
import mysql.connector
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Query to fetch Blood Type distribution
query = """
SELECT Blood_Type, COUNT(*) AS patient_count
FROM patients
GROUP BY Blood_Type
ORDER BY patient_count DESC;
"""

# Execute the query
cur.execute(query)
data = cur.fetchall()

# Convert the result into a Pandas DataFrame
df = pd.DataFrame(data, columns=["Blood_Type", "patient_count"])

# Visualization: Pie chart for Blood Type distribution
plt.figure(figsize=(8, 8))
plt.pie(
    df["patient_count"],
    labels=df["Blood_Type"],
    autopct='%1.1f%%',
    startangle=140,
    colors=sns.color_palette('pastel')
)
plt.title('Distribution of Patients by Blood Type')
plt.show()

# %%
import mysql.connector
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Query to fetch Age Group distribution
query = """
SELECT 
    CASE 
        WHEN Age BETWEEN 0 AND 18 THEN '0-18'
        WHEN Age BETWEEN 19 AND 50 THEN '19-50'
        ELSE '50+' 
    END AS Age_Group,
    COUNT(*) AS patient_count
FROM patients
GROUP BY Age_Group
ORDER BY patient_count DESC;
"""

# Execute the query
cur.execute(query)
data = cur.fetchall()

# Convert the result into a Pandas DataFrame
df = pd.DataFrame(data, columns=["Age_Group", "patient_count"])

# Visualization: Bar plot for Age Group distribution
plt.figure(figsize=(10, 6))
sns.barplot(x="Age_Group", y="patient_count", data=df, palette="Blues_d")
plt.title('Distribution of Patients by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Number of Patients')
plt.show()

# %%
#Number of Patients per Doctor

import mysql.connector
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Query to fetch the number of patients per doctor
query = """
SELECT Doctor, COUNT(*) AS patient_count
FROM patients
GROUP BY Doctor
ORDER BY patient_count DESC
LIMIT 10;
"""

# Execute the query
cur.execute(query)
data = cur.fetchall()

# Convert the result into a Pandas DataFrame
df = pd.DataFrame(data, columns=["Doctor", "patient_count"])

# Visualization: Bar plot for the number of patients per doctor
plt.figure(figsize=(12, 6))
sns.barplot(x="patient_count", y="Doctor", data=df, palette="deep")
plt.title('Top 10 Doctors by Number of Patients')
plt.xlabel('Number of Patients')
plt.ylabel('Doctor')
plt.show()
